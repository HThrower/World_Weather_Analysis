# %%
# Import the dependencies.
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_url)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        print(weather_description)
        try:
            rain_inches = city_weather["rain"]["3h"]
        except:
            rain_inches = ("0")
            pass
        try:
            snow_inches = city_weather["snow"]["3h"]
        except:
            snow_inches = ("0")  
            pass
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        print(city_date)
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Rain inches (last 3 hours)": rain_inches,
                          "Snow inches (last 3 hours)": snow_inches})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lompoc
# clear sky
# 2021-11-07 00:38:30
# Processing Record 4 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ushuaia
# light intensity drizzle
# 2021-11-07 00:36:10
# Processing Record 5 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kruisfontein
# overcast clouds
# 2021-11-07 00:38:30
# Processing Record 6 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hithadhoo
# overcast clouds
# 2021-11-07 00:38:31
# Processing Record 7 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hermanus
# few clouds
# 2021-11-07 00:38:31
# Processing Record 8 of Set 1 | niquelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=niquelandia
# overcast clouds
# 2021-11-07 00:38:31
# Processing Record 9 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bluff
# overcast clouds
# 2021-11-07 00:36:35
# Processing Record 10 of Set 1 | chanika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chanika
# overcast clouds
# 2021-11-07 00:38:32
# Processing Record 11 of Set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=sao filipe
# broken clouds
# 2021-11-07 00:35:05
# Processing Record 12 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=rikitea
# overcast clouds
# 2021-11-07 00:38:32
# Processing Record 13 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=balikpapan
# few clouds
# 2021-11-07 00:38:33
# Processing Record 15 of Set 1 | adzope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=adzope
# overcast clouds
# 2021-11-07 00:38:33
# Processing Record 16 of Set 1 | naron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=naron
# clear sky
# 2021-11-07 00:38:34
# Processing Record 17 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kapaa
# light rain
# 2021-11-07 00:38:34
# Processing Record 18 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tuktoyaktuk
# few clouds
# 2021-11-07 00:38:34
# Processing Record 19 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cape town
# clear sky
# 2021-11-07 00:35:09
# Processing Record 20 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mataura
# broken clouds
# 2021-11-07 00:33:51
# Processing Record 21 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port hedland
# broken clouds
# 2021-11-07 00:38:35
# Processing Record 22 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=portland
# moderate rain
# 2021-11-07 00:34:00
# Processing Record 23 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saint george
# clear sky
# 2021-11-07 00:36:05
# Processing Record 24 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | novyy urgal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=novyy urgal
# clear sky
# 2021-11-07 00:38:36
# Processing Record 26 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saskylakh
# scattered clouds
# 2021-11-07 00:38:36
# Processing Record 27 of Set 1 | chadiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chadiza
# scattered clouds
# 2021-11-07 00:38:36
# Processing Record 28 of Set 1 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=griffith
# clear sky
# 2021-11-07 00:38:37
# Processing Record 29 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vaini
# broken clouds
# 2021-11-07 00:38:37
# Processing Record 30 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=puerto ayora
# scattered clouds
# 2021-11-07 00:38:37
# Processing Record 31 of Set 1 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ugoofaaru
# overcast clouds
# 2021-11-07 00:38:38
# Processing Record 32 of Set 1 | simbahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=simbahan
# broken clouds
# 2021-11-07 00:38:38
# Processing Record 33 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=carnarvon
# scattered clouds
# 2021-11-07 00:38:38
# Processing Record 34 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saint-philippe
# scattered clouds
# 2021-11-07 00:38:39
# Processing Record 35 of Set 1 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=okhotsk
# overcast clouds
# 2021-11-07 00:38:39
# Processing Record 36 of Set 1 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=viligili
# City not found. Skipping...
# Processing Record 38 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=georgetown
# few clouds
# 2021-11-07 00:38:40
# Processing Record 39 of Set 1 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bontang
# overcast clouds
# 2021-11-07 00:38:40
# Processing Record 40 of Set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=albany
# clear sky
# 2021-11-07 00:36:25
# Processing Record 42 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=dikson
# light snow
# 2021-11-07 00:38:41
# Processing Record 43 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saint anthony
# clear sky
# 2021-11-07 00:38:41
# Processing Record 44 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=upata
# overcast clouds
# 2021-11-07 00:38:41
# Processing Record 46 of Set 1 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=olinda
# scattered clouds
# 2021-11-07 00:38:42
# Processing Record 47 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=padang
# light rain
# 2021-11-07 00:38:42
# Processing Record 48 of Set 1 | itumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=itumba
# overcast clouds
# 2021-11-07 00:38:42
# Processing Record 49 of Set 1 | canandaigua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=canandaigua
# clear sky
# 2021-11-07 00:38:43
# Processing Record 50 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port lincoln
# overcast clouds
# 2021-11-07 00:38:43
# Processing Record 1 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=leningradskiy
# clear sky
# 2021-11-07 00:38:43
# Processing Record 2 of Set 2 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=belaya gora
# scattered clouds
# 2021-11-07 00:38:44
# Processing Record 3 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ponta do sol
# scattered clouds
# 2021-11-07 00:37:38
# Processing Record 4 of Set 2 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lata
# clear sky
# 2021-11-07 00:38:44
# Processing Record 5 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hilo
# broken clouds
# 2021-11-07 00:33:56
# Processing Record 6 of Set 2 | madawaska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=madawaska
# clear sky
# 2021-11-07 00:38:45
# Processing Record 7 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=iqaluit
# scattered clouds
# 2021-11-07 00:38:45
# Processing Record 8 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=souillac
# scattered clouds
# 2021-11-07 00:38:45
# Processing Record 9 of Set 2 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=usinsk
# light rain
# 2021-11-07 00:38:46
# Processing Record 10 of Set 2 | issa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=issa
# overcast clouds
# 2021-11-07 00:38:46
# Processing Record 11 of Set 2 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lasa
# clear sky
# 2021-11-07 00:38:46
# Processing Record 12 of Set 2 | capaci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=capaci
# clear sky
# 2021-11-07 00:38:47
# Processing Record 13 of Set 2 | guebwiller
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=guebwiller
# overcast clouds
# 2021-11-07 00:38:47
# Processing Record 14 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=torbay
# overcast clouds
# 2021-11-07 00:35:31
# Processing Record 15 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ancud
# clear sky
# 2021-11-07 00:38:48
# Processing Record 16 of Set 2 | san roque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=san roque
# clear sky
# 2021-11-07 00:38:48
# Processing Record 17 of Set 2 | brandon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=brandon
# overcast clouds
# 2021-11-07 00:38:48
# Processing Record 18 of Set 2 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=coos bay
# broken clouds
# 2021-11-07 00:38:49
# Processing Record 19 of Set 2 | tecolutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tecolutla
# broken clouds
# 2021-11-07 00:38:49
# Processing Record 20 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cabo san lucas
# scattered clouds
# 2021-11-07 00:35:13
# Processing Record 21 of Set 2 | malwan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=malwan
# City not found. Skipping...
# Processing Record 22 of Set 2 | nizhneangarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nizhneangarsk
# overcast clouds
# 2021-11-07 00:38:50
# Processing Record 23 of Set 2 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hirara
# few clouds
# 2021-11-07 00:38:50
# Processing Record 24 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=arraial do cabo
# clear sky
# 2021-11-07 00:37:31
# Processing Record 25 of Set 2 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cockburn town
# scattered clouds
# 2021-11-07 00:38:51
# Processing Record 26 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=thompson
# overcast clouds
# 2021-11-07 00:38:51
# Processing Record 27 of Set 2 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=halalo
# City not found. Skipping...
# Processing Record 28 of Set 2 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nelson bay
# light rain
# 2021-11-07 00:38:51
# Processing Record 29 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port alfred
# light rain
# 2021-11-07 00:38:52
# Processing Record 30 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yellowknife
# broken clouds
# 2021-11-07 00:35:25
# Processing Record 31 of Set 2 | burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=burica
# City not found. Skipping...
# Processing Record 32 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hobart
# broken clouds
# 2021-11-07 00:38:52
# Processing Record 33 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mount gambier
# overcast clouds
# 2021-11-07 00:36:08
# Processing Record 34 of Set 2 | karamea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=karamea
# City not found. Skipping...
# Processing Record 35 of Set 2 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nouadhibou
# clear sky
# 2021-11-07 00:38:53
# Processing Record 36 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=luderitz
# clear sky
# 2021-11-07 00:38:53
# Processing Record 37 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=castro
# few clouds
# 2021-11-07 00:38:54
# Processing Record 38 of Set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kavieng
# light rain
# 2021-11-07 00:38:54
# Processing Record 39 of Set 2 | karema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=karema
# overcast clouds
# 2021-11-07 00:38:54
# Processing Record 40 of Set 2 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saint-georges
# few clouds
# 2021-11-07 00:38:54
# Processing Record 41 of Set 2 | novopskov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=novopskov
# clear sky
# 2021-11-07 00:38:55
# Processing Record 42 of Set 2 | kumylzhenskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kumylzhenskaya
# scattered clouds
# 2021-11-07 00:38:55
# Processing Record 43 of Set 2 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=los llanos de aridane
# broken clouds
# 2021-11-07 00:38:56
# Processing Record 44 of Set 2 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lagoa
# scattered clouds
# 2021-11-07 00:38:56
# Processing Record 46 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bredasdorp
# scattered clouds
# 2021-11-07 00:38:56
# Processing Record 47 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=punta arenas
# overcast clouds
# 2021-11-07 00:38:57
# Processing Record 48 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=east london
# light rain
# 2021-11-07 00:34:01
# Processing Record 49 of Set 2 | wau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=wau
# broken clouds
# 2021-11-07 00:38:57
# Processing Record 50 of Set 2 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=sorong
# broken clouds
# 2021-11-07 00:38:58
# Processing Record 1 of Set 3 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kenora
# scattered clouds
# 2021-11-07 00:38:58
# Processing Record 2 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ribeira grande
# overcast clouds
# 2021-11-07 00:38:58
# Processing Record 3 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kaitangata
# overcast clouds
# 2021-11-07 00:38:59
# Processing Record 4 of Set 3 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=gat
# clear sky
# 2021-11-07 00:38:59
# Processing Record 5 of Set 3 | holoby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=holoby
# clear sky
# 2021-11-07 00:38:59
# Processing Record 6 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=avarua
# broken clouds
# 2021-11-07 00:39:00
# Processing Record 7 of Set 3 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vestmanna
# overcast clouds
# 2021-11-07 00:39:00
# Processing Record 8 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=constitucion
# few clouds
# 2021-11-07 00:39:00
# Processing Record 9 of Set 3 | pagudpud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pagudpud
# clear sky
# 2021-11-07 00:39:01
# Processing Record 10 of Set 3 | pervoye maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pervoye maya
# overcast clouds
# 2021-11-07 00:39:02
# Processing Record 11 of Set 3 | nushki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nushki
# clear sky
# 2021-11-07 00:39:03
# Processing Record 12 of Set 3 | banfora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=banfora
# clear sky
# 2021-11-07 00:39:03
# Processing Record 13 of Set 3 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=viedma
# overcast clouds
# 2021-11-07 00:36:17
# Processing Record 14 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chuy
# clear sky
# 2021-11-07 00:39:04
# Processing Record 15 of Set 3 | yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yangambi
# moderate rain
# 2021-11-07 00:39:04
# Processing Record 16 of Set 3 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=zhangjiakou
# overcast clouds
# 2021-11-07 00:39:04
# Processing Record 17 of Set 3 | luangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=luangwa
# clear sky
# 2021-11-07 00:39:05
# Processing Record 18 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=codrington
# overcast clouds
# 2021-11-07 00:39:05
# Processing Record 20 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cherskiy
# light snow
# 2021-11-07 00:38:55
# Processing Record 21 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=batemans bay
# broken clouds
# 2021-11-07 00:39:06
# Processing Record 23 of Set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nome
# overcast clouds
# 2021-11-07 00:39:06
# Processing Record 24 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=atuona
# clear sky
# 2021-11-07 00:39:07
# Processing Record 25 of Set 3 | yucca valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yucca valley
# clear sky
# 2021-11-07 00:35:35
# Processing Record 26 of Set 3 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=juneau
# scattered clouds
# 2021-11-07 00:39:07
# Processing Record 27 of Set 3 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=khonuu
# City not found. Skipping...
# Processing Record 28 of Set 3 | canguaretama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=canguaretama
# few clouds
# 2021-11-07 00:39:08
# Processing Record 29 of Set 3 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 3 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ishigaki
# few clouds
# 2021-11-07 00:39:08
# Processing Record 31 of Set 3 | kabompo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kabompo
# clear sky
# 2021-11-07 00:39:08
# Processing Record 32 of Set 3 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=thinadhoo
# overcast clouds
# 2021-11-07 00:37:03
# Processing Record 33 of Set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=airai
# scattered clouds
# 2021-11-07 00:39:09
# Processing Record 34 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=talnakh
# light snow
# 2021-11-07 00:38:59
# Processing Record 35 of Set 3 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=abu dhabi
# clear sky
# 2021-11-07 00:39:09
# Processing Record 36 of Set 3 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pangnirtung
# few clouds
# 2021-11-07 00:39:10
# Processing Record 37 of Set 3 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vila franca do campo
# clear sky
# 2021-11-07 00:39:10
# Processing Record 38 of Set 3 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=sembe
# overcast clouds
# 2021-11-07 00:39:10
# Processing Record 39 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=upernavik
# overcast clouds
# 2021-11-07 00:39:11
# Processing Record 40 of Set 3 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chagda
# City not found. Skipping...
# Processing Record 41 of Set 3 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=inhambane
# broken clouds
# 2021-11-07 00:39:11
# Processing Record 42 of Set 3 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yeppoon
# overcast clouds
# 2021-11-07 00:39:11
# Processing Record 43 of Set 3 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tessalit
# broken clouds
# 2021-11-07 00:39:12
# Processing Record 44 of Set 3 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=orlik
# overcast clouds
# 2021-11-07 00:39:12
# Processing Record 45 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bethel
# clear sky
# 2021-11-07 00:36:22
# Processing Record 46 of Set 3 | yarensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yarensk
# overcast clouds
# 2021-11-07 00:39:13
# Processing Record 47 of Set 3 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kodinsk
# overcast clouds
# 2021-11-07 00:39:13
# Processing Record 48 of Set 3 | kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kushima
# scattered clouds
# 2021-11-07 00:39:13
# Processing Record 49 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port blair
# overcast clouds
# 2021-11-07 00:39:14
# Processing Record 50 of Set 3 | crab hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=crab hill
# City not found. Skipping...
# Processing Record 1 of Set 4 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=rawson
# overcast clouds
# 2021-11-07 00:39:14
# Processing Record 2 of Set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=jamestown
# clear sky
# 2021-11-07 00:38:34
# Processing Record 3 of Set 4 | yanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yanan
# City not found. Skipping...
# Processing Record 4 of Set 4 | whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=whitianga
# broken clouds
# 2021-11-07 00:39:15
# Processing Record 5 of Set 4 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=comodoro rivadavia
# clear sky
# 2021-11-07 00:39:15
# Processing Record 6 of Set 4 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=husavik
# light rain
# 2021-11-07 00:35:03
# Processing Record 7 of Set 4 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yinchuan
# clear sky
# 2021-11-07 00:39:16
# Processing Record 8 of Set 4 | cloquet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cloquet
# clear sky
# 2021-11-07 00:39:16
# Processing Record 9 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mahebourg
# scattered clouds
# 2021-11-07 00:39:16
# Processing Record 10 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hofn
# light rain
# 2021-11-07 00:39:17
# Processing Record 11 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nanortalik
# overcast clouds
# 2021-11-07 00:39:17
# Processing Record 12 of Set 4 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=san quintin
# clear sky
# 2021-11-07 00:37:49
# Processing Record 13 of Set 4 | port lavaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port lavaca
# clear sky
# 2021-11-07 00:39:18
# Processing Record 14 of Set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ostrovnoy
# snow
# 2021-11-07 00:39:18
# Processing Record 15 of Set 4 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=busselton
# few clouds
# 2021-11-07 00:39:18
# Processing Record 16 of Set 4 | maryanovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=maryanovka
# City not found. Skipping...
# Processing Record 17 of Set 4 | taldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=taldan
# overcast clouds
# 2021-11-07 00:39:19
# Processing Record 18 of Set 4 | shawville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=shawville
# broken clouds
# 2021-11-07 00:39:19
# Processing Record 19 of Set 4 | nenita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nenita
# overcast clouds
# 2021-11-07 00:39:19
# Processing Record 20 of Set 4 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hami
# clear sky
# 2021-11-07 00:39:20
# Processing Record 21 of Set 4 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=aswan
# clear sky
# 2021-11-07 00:39:20
# Processing Record 22 of Set 4 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pevek
# overcast clouds
# 2021-11-07 00:39:21
# Processing Record 24 of Set 4 | cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cervo
# clear sky
# 2021-11-07 00:39:21
# Processing Record 25 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kodiak
# clear sky
# 2021-11-07 00:39:21
# Processing Record 26 of Set 4 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=stornoway
# overcast clouds
# 2021-11-07 00:39:22
# Processing Record 27 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=khatanga
# overcast clouds
# 2021-11-07 00:37:47
# Processing Record 28 of Set 4 | alpena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=alpena
# clear sky
# 2021-11-07 00:39:22
# Processing Record 29 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=qaanaaq
# overcast clouds
# 2021-11-07 00:39:23
# Processing Record 30 of Set 4 | rumoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=rumoi
# overcast clouds
# 2021-11-07 00:39:15
# Processing Record 31 of Set 4 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=daru
# scattered clouds
# 2021-11-07 00:39:23
# Processing Record 32 of Set 4 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=halifax
# clear sky
# 2021-11-07 00:36:01
# Processing Record 33 of Set 4 | saint-raphael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saint-raphael
# broken clouds
# 2021-11-07 00:39:24
# Processing Record 34 of Set 4 | buzmeyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=buzmeyin
# few clouds
# 2021-11-07 00:39:24
# Processing Record 35 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mar del plata
# overcast clouds
# 2021-11-07 00:39:10
# Processing Record 36 of Set 4 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tazovskiy
# overcast clouds
# 2021-11-07 00:39:25
# Processing Record 37 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lebu
# scattered clouds
# 2021-11-07 00:39:25
# Processing Record 38 of Set 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vardo
# overcast clouds
# 2021-11-07 00:39:25
# Processing Record 39 of Set 4 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=saldanha
# overcast clouds
# 2021-11-07 00:39:26
# Processing Record 40 of Set 4 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=harper
# few clouds
# 2021-11-07 00:39:26
# Processing Record 41 of Set 4 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=araouane
# broken clouds
# 2021-11-07 00:39:26
# Processing Record 42 of Set 4 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=taoudenni
# clear sky
# 2021-11-07 00:39:27
# Processing Record 43 of Set 4 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bac lieu
# broken clouds
# 2021-11-07 00:39:27
# Processing Record 44 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=katsuura
# overcast clouds
# 2021-11-07 00:38:59
# Processing Record 45 of Set 4 | pombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pombia
# clear sky
# 2021-11-07 00:39:27
# Processing Record 46 of Set 4 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=fukue
# few clouds
# 2021-11-07 00:39:28
# Processing Record 47 of Set 4 | andahuaylas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=andahuaylas
# overcast clouds
# 2021-11-07 00:39:28
# Processing Record 48 of Set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bilma
# overcast clouds
# 2021-11-07 00:36:21
# Processing Record 49 of Set 4 | raahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=raahe
# overcast clouds
# 2021-11-07 00:39:29
# Processing Record 50 of Set 4 | yankton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yankton
# clear sky
# 2021-11-07 00:37:45
# Processing Record 1 of Set 5 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nuuk
# broken clouds
# 2021-11-07 00:36:05
# Processing Record 2 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port elizabeth
# broken clouds
# 2021-11-07 00:38:55
# Processing Record 3 of Set 5 | banikoara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=banikoara
# broken clouds
# 2021-11-07 00:39:29
# Processing Record 4 of Set 5 | heihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=heihe
# clear sky
# 2021-11-07 00:39:30
# Processing Record 5 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=namibe
# overcast clouds
# 2021-11-07 00:39:30
# Processing Record 6 of Set 5 | teodoro sampaio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=teodoro sampaio
# overcast clouds
# 2021-11-07 00:39:30
# Processing Record 7 of Set 5 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=makakilo city
# few clouds
# 2021-11-07 00:39:31
# Processing Record 8 of Set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=vostok
# overcast clouds
# 2021-11-07 00:39:31
# Processing Record 9 of Set 5 | riberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=riberalta
# overcast clouds
# 2021-11-07 00:39:31
# Processing Record 10 of Set 5 | sosnovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=sosnovka
# overcast clouds
# 2021-11-07 00:39:32
# Processing Record 11 of Set 5 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=hobyo
# broken clouds
# 2021-11-07 00:36:22
# Processing Record 12 of Set 5 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=clyde river
# scattered clouds
# 2021-11-07 00:39:32
# Processing Record 13 of Set 5 | liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=liverpool
# scattered clouds
# 2021-11-07 00:36:11
# Processing Record 14 of Set 5 | la serena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=la serena
# clear sky
# 2021-11-07 00:39:33
# Processing Record 15 of Set 5 | venice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=venice
# broken clouds
# 2021-11-07 00:38:42
# Processing Record 16 of Set 5 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kutum
# clear sky
# 2021-11-07 00:39:33
# Processing Record 17 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=severo-kurilsk
# scattered clouds
# 2021-11-07 00:36:24
# Processing Record 18 of Set 5 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=rocha
# few clouds
# 2021-11-07 00:39:34
# Processing Record 19 of Set 5 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=beringovskiy
# scattered clouds
# 2021-11-07 00:39:34
# Processing Record 20 of Set 5 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mercedes
# overcast clouds
# 2021-11-07 00:39:35
# Processing Record 21 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tiksi
# overcast clouds
# 2021-11-07 00:39:35
# Processing Record 22 of Set 5 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=deputatskiy
# overcast clouds
# 2021-11-07 00:39:35
# Processing Record 23 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=esperance
# scattered clouds
# 2021-11-07 00:39:36
# Processing Record 24 of Set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yar-sale
# overcast clouds
# 2021-11-07 00:39:36
# Processing Record 25 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=narsaq
# overcast clouds
# 2021-11-07 00:39:36
# Processing Record 26 of Set 5 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bambous virieux
# scattered clouds
# 2021-11-07 00:39:37
# Processing Record 27 of Set 5 | pavlogradka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=pavlogradka
# overcast clouds
# 2021-11-07 00:39:37
# Processing Record 28 of Set 5 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=huarmey
# overcast clouds
# 2021-11-07 00:39:37
# Processing Record 29 of Set 5 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kaeo
# scattered clouds
# 2021-11-07 00:39:38
# Processing Record 30 of Set 5 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=muros
# clear sky
# 2021-11-07 00:39:38
# Processing Record 31 of Set 5 | belaya kholunitsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=belaya kholunitsa
# overcast clouds
# 2021-11-07 00:39:38
# Processing Record 32 of Set 5 | chardara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chardara
# clear sky
# 2021-11-07 00:39:39
# Processing Record 33 of Set 5 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=sept-iles
# broken clouds
# 2021-11-07 00:35:10
# Processing Record 34 of Set 5 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tromso
# clear sky
# 2021-11-07 00:39:39
# Processing Record 35 of Set 5 | senekal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=senekal
# clear sky
# 2021-11-07 00:39:39
# Processing Record 36 of Set 5 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kloulklubed
# overcast clouds
# 2021-11-07 00:39:40
# Processing Record 37 of Set 5 | la ligua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=la ligua
# clear sky
# 2021-11-07 00:39:40
# Processing Record 38 of Set 5 | kegayli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kegayli
# City not found. Skipping...
# Processing Record 39 of Set 5 | lindenhurst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lindenhurst
# clear sky
# 2021-11-07 00:38:57
# Processing Record 40 of Set 5 | umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=umba
# overcast clouds
# 2021-11-07 00:39:41
# Processing Record 41 of Set 5 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=luanda
# light rain
# 2021-11-07 00:39:41
# Processing Record 42 of Set 5 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=samarai
# clear sky
# 2021-11-07 00:39:41
# Processing Record 43 of Set 5 | lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lashio
# clear sky
# 2021-11-07 00:39:42
# Processing Record 44 of Set 5 | rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=rincon
# overcast clouds
# 2021-11-07 00:37:49
# Processing Record 45 of Set 5 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=finschhafen
# broken clouds
# 2021-11-07 00:39:42
# Processing Record 46 of Set 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lavrentiya
# broken clouds
# 2021-11-07 00:39:43
# Processing Record 47 of Set 5 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=burns lake
# overcast clouds
# 2021-11-07 00:39:43
# Processing Record 48 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=te anau
# overcast clouds
# 2021-11-07 00:35:49
# Processing Record 50 of Set 5 | fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=fairlie
# overcast clouds
# 2021-11-07 00:39:43
# Processing Record 1 of Set 6 | manyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=manyana
# overcast clouds
# 2021-11-07 00:39:44
# Processing Record 2 of Set 6 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=altay
# overcast clouds
# 2021-11-07 00:39:44
# Processing Record 3 of Set 6 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=westport
# clear sky
# 2021-11-07 00:39:45
# Processing Record 4 of Set 6 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=verkhoyansk
# scattered clouds
# 2021-11-07 00:39:45
# Processing Record 5 of Set 6 | north port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=north port
# overcast clouds
# 2021-11-07 00:39:45
# Processing Record 6 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=provideniya
# light snow
# 2021-11-07 00:39:46
# Processing Record 7 of Set 6 | jahrom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=jahrom
# City not found. Skipping...
# ...
# clear sky
# 2021-11-07 00:41:15
# Processing Record 30 of Set 11 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=banda aceh
# overcast clouds
# 2021-11-07 00:40:08
# Processing Record 31 of Set 11 | yusva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yusva
# City not found. Skipping...
# Processing Record 32 of Set 11 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=north bend
# broken clouds
# 2021-11-07 00:41:15
# Processing Record 33 of Set 11 | shirokiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=shirokiy
# clear sky
# 2021-11-07 00:41:16
# Processing Record 34 of Set 11 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mnogovershinnyy
# overcast clouds
# 2021-11-07 00:41:16
# Processing Record 35 of Set 11 | ziro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ziro
# broken clouds
# 2021-11-07 00:41:16
# Processing Record 36 of Set 11 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=matagami
# overcast clouds
# 2021-11-07 00:39:06
# Processing Record 37 of Set 11 | muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=muzhi
# broken clouds
# 2021-11-07 00:41:17
# Processing Record 38 of Set 11 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=omboue
# overcast clouds
# 2021-11-07 00:41:17
# Processing Record 39 of Set 11 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=launceston
# broken clouds
# 2021-11-07 00:41:18
# Processing Record 40 of Set 11 | thurso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=thurso
# overcast clouds
# 2021-11-07 00:38:12
# Processing Record 41 of Set 11 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mizan teferi
# overcast clouds
# 2021-11-07 00:41:18
# Processing Record 42 of Set 11 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bandarbeyla
# scattered clouds
# 2021-11-07 00:41:19
# Processing Record 43 of Set 11 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=victoria
# clear sky
# 2021-11-07 00:37:15
# Processing Record 44 of Set 11 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=batagay-alyta
# overcast clouds
# 2021-11-07 00:41:19
# Processing Record 45 of Set 11 | mineiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=mineiros
# overcast clouds
# 2021-11-07 00:41:20
# Processing Record 46 of Set 11 | conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=conde
# few clouds
# 2021-11-07 00:41:20
# Processing Record 47 of Set 11 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kalabo
# broken clouds
# 2021-11-07 00:41:20
# Processing Record 48 of Set 11 | paraguacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=paraguacu
# scattered clouds
# 2021-11-07 00:41:21
# Processing Record 49 of Set 11 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=san patricio
# clear sky
# 2021-11-07 00:40:13
# Processing Record 50 of Set 11 | murakami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=murakami
# clear sky
# 2021-11-07 00:41:21
# Processing Record 1 of Set 12 | monte escobedo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=monte escobedo
# clear sky
# 2021-11-07 00:41:22
# Processing Record 2 of Set 12 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=miyako
# clear sky
# 2021-11-07 00:41:22
# Processing Record 3 of Set 12 | fergus falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=fergus falls
# clear sky
# 2021-11-07 00:41:22
# Processing Record 4 of Set 12 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=qui nhon
# scattered clouds
# 2021-11-07 00:41:23
# Processing Record 5 of Set 12 | churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=churapcha
# overcast clouds
# 2021-11-07 00:41:23
# Processing Record 6 of Set 12 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=havoysund
# light snow
# 2021-11-07 00:41:23
# Processing Record 7 of Set 12 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=alihe
# clear sky
# 2021-11-07 00:41:24
# Processing Record 8 of Set 12 | santa vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=santa vitoria
# broken clouds
# 2021-11-07 00:41:24
# Processing Record 9 of Set 12 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port augusta
# scattered clouds
# 2021-11-07 00:40:19
# Processing Record 10 of Set 12 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yerbogachen
# broken clouds
# 2021-11-07 00:41:25
# Processing Record 11 of Set 12 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=balkanabat
# broken clouds
# 2021-11-07 00:41:25
# Processing Record 12 of Set 12 | machaneng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=machaneng
# light rain
# 2021-11-07 00:41:25
# Processing Record 13 of Set 12 | la baule-escoublac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=la baule-escoublac
# overcast clouds
# 2021-11-07 00:41:26
# Processing Record 14 of Set 12 | botwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=botwood
# few clouds
# 2021-11-07 00:41:26
# Processing Record 15 of Set 12 | yabrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=yabrud
# clear sky
# 2021-11-07 00:41:26
# Processing Record 16 of Set 12 | aguada de pasajeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=aguada de pasajeros
# overcast clouds
# 2021-11-07 00:41:27
# Processing Record 17 of Set 12 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=asau
# light rain
# 2021-11-07 00:41:27
# Processing Record 18 of Set 12 | nigde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=nigde
# clear sky
# 2021-11-07 00:41:27
# Processing Record 19 of Set 12 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=inuvik
# scattered clouds
# 2021-11-07 00:41:28
# Processing Record 20 of Set 12 | ardesen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ardesen
# overcast clouds
# 2021-11-07 00:41:28
# Processing Record 21 of Set 12 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ilhabela
# broken clouds
# 2021-11-07 00:41:28
# Processing Record 22 of Set 12 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ndele
# overcast clouds
# 2021-11-07 00:41:29
# Processing Record 23 of Set 12 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=dukat
# overcast clouds
# 2021-11-07 00:41:29
# Processing Record 24 of Set 12 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=watsa
# clear sky
# 2021-11-07 00:41:30
# Processing Record 25 of Set 12 | changji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=changji
# clear sky
# 2021-11-07 00:41:30
# Processing Record 26 of Set 12 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=karratha
# clear sky
# 2021-11-07 00:41:23
# Processing Record 27 of Set 12 | gabriel leyva solano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=gabriel leyva solano
# overcast clouds
# 2021-11-07 00:41:30
# Processing Record 28 of Set 12 | graaff-reinet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=graaff-reinet
# light rain
# 2021-11-07 00:37:26
# Processing Record 29 of Set 12 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kasongo-lunda
# overcast clouds
# 2021-11-07 00:41:31
# Processing Record 30 of Set 12 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=barcelos
# clear sky
# 2021-11-07 00:41:31
# Processing Record 31 of Set 12 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=coahuayana
# overcast clouds
# 2021-11-07 00:41:32
# Processing Record 32 of Set 12 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=kangaatsiaq
# overcast clouds
# 2021-11-07 00:41:32
# Processing Record 33 of Set 12 | zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=zhanakorgan
# clear sky
# 2021-11-07 00:41:32
# Processing Record 34 of Set 12 | tucurui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tucurui
# overcast clouds
# 2021-11-07 00:41:33
# Processing Record 35 of Set 12 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=moose factory
# overcast clouds
# 2021-11-07 00:41:33
# Processing Record 36 of Set 12 | chake chake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=chake chake
# broken clouds
# 2021-11-07 00:41:33
# Processing Record 37 of Set 12 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=aklavik
# overcast clouds
# 2021-11-07 00:41:34
# Processing Record 38 of Set 12 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=prince rupert
# light rain
# 2021-11-07 00:41:34
# Processing Record 39 of Set 12 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port-gentil
# overcast clouds
# 2021-11-07 00:41:34
# Processing Record 40 of Set 12 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=dauphin
# clear sky
# 2021-11-07 00:41:35
# Processing Record 41 of Set 12 | itapetinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=itapetinga
# overcast clouds
# 2021-11-07 00:40:14
# Processing Record 42 of Set 12 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=palmer
# clear sky
# 2021-11-07 00:41:35
# Processing Record 43 of Set 12 | muriae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=muriae
# overcast clouds
# 2021-11-07 00:41:35
# Processing Record 44 of Set 12 | obo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=obo
# few clouds
# 2021-11-07 00:41:36
# Processing Record 45 of Set 12 | campo maior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=campo maior
# scattered clouds
# 2021-11-07 00:41:36
# Processing Record 46 of Set 12 | tubruq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=tubruq
# City not found. Skipping...
# Processing Record 47 of Set 12 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=port hardy
# broken clouds
# 2021-11-07 00:41:37
# Processing Record 48 of Set 12 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=cidreira
# overcast clouds
# 2021-11-07 00:41:37
# Processing Record 49 of Set 12 | alekseyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=alekseyevka
# clear sky
# 2021-11-07 00:41:37
# Processing Record 50 of Set 12 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=shelburne
# broken clouds
# 2021-11-07 00:41:29
# Processing Record 1 of Set 13 | locri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=locri
# overcast clouds
# 2021-11-07 00:41:38
# Processing Record 2 of Set 13 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ginir
# clear sky
# 2021-11-07 00:41:38
# Processing Record 3 of Set 13 | ilinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ilinskiy
# light intensity shower rain
# 2021-11-07 00:41:38
# Processing Record 4 of Set 13 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=necochea
# overcast clouds
# 2021-11-07 00:37:46
# Processing Record 5 of Set 13 | lianzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=lianzhou
# overcast clouds
# 2021-11-07 00:41:39
# Processing Record 6 of Set 13 | creel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=creel
# few clouds
# 2021-11-07 00:41:39
# Processing Record 7 of Set 13 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=peniche
# clear sky
# 2021-11-07 00:41:40
# Processing Record 8 of Set 13 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=salalah
# overcast clouds
# 2021-11-07 00:40:19
# Processing Record 9 of Set 13 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=dingle
# overcast clouds
# 2021-11-07 00:38:52
# Processing Record 10 of Set 13 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=bowen
# overcast clouds
# 2021-11-07 00:41:40
# Processing Record 11 of Set 13 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=ambilobe
# clear sky
# 2021-11-07 00:41:41
# Processing Record 12 of Set 13 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=richards bay
# overcast clouds
# 2021-11-07 00:41:41
# Processing Record 13 of Set 13 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c069ed35f1122d3e26150be7fa2f0da3&q=miri
# scattered clouds
# 2021-11-07 00:41:41
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df = pd.DataFrame(city_data)
#WeatherPy_Database_df.head(10)
city_data_df.to_csv('WeatherPy_Database.csv')

# %%
sum(city_data_df["Rain inches (last 3 hours)"]!="0")
# Out:
# 0

# %%
sum(city_data_df["Snow inches (last 3 hours)"]!="0")
# Out:
# 0
